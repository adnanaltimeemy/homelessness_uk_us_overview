# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer

import matplotlib.pyplot as plt
import seaborn as sns

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/adnanaltimeemy/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/adnanaltimeemy/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Load CSV file
df = pd.read_csv("State Homelessness Breakdown.csv")

# View dataset
df.head()
# Out:
#                                    ID         State             Variable  \
# 0          Guam - Chronic individuals          Guam  Chronic individuals
# 1      New York - Chronic individuals      New York  Chronic individuals
# 2         Maine - Chronic individuals         Maine  Chronic individuals
# 3  North Dakota - Chronic individuals  North Dakota  Chronic individuals
# 4      Delaware - Chronic individuals      Delaware  Chronic individuals
#
#     2013   2012 %  Change from 2012  \
# 0     51     22             131.82%
# 1  4,045  4,324              -6.45%
# 2    159    222             -28.38%
# 3    110     81              35.80%
# 4     65     84             -22.62%
#
#   Percentage of Total Homeless Populaiton (2013)  Rate per 10,000
# 0                                           4.0%             3.20
# 1                                           5.2%             2.06
# 2                                           5.3%             1.20
# 3                                           5.3%             1.52
# 4                                           6.9%             0.70

# %%
print(df.columns)
# Out:
# Index(['ID', 'State', 'Variable', '2013', '2012', '%  Change from 2012',
#        'Percentage of Total Homeless Populaiton (2013)', 'Rate per 10,000'],
#       dtype='str')

# %%
df.columns.tolist()
# Out:
# ['ID',
#  'State',
#  'Variable',
#  '2013',
#  '2012',
#  '%  Change from 2012',
#  'Percentage of Total Homeless Populaiton (2013)',
#  'Rate per 10,000']

# %%
df.head()
df.columns
# Out:
# Index(['ID', 'State', 'Variable', '2013', '2012', '%  Change from 2012',
#        'Percentage of Total Homeless Populaiton (2013)', 'Rate per 10,000'],
#       dtype='str')

# %%
df.head()
# Out:
#                                    ID         State             Variable  \
# 0          Guam - Chronic individuals          Guam  Chronic individuals
# 1      New York - Chronic individuals      New York  Chronic individuals
# 2         Maine - Chronic individuals         Maine  Chronic individuals
# 3  North Dakota - Chronic individuals  North Dakota  Chronic individuals
# 4      Delaware - Chronic individuals      Delaware  Chronic individuals
#
#     2013   2012 %  Change from 2012  \
# 0     51     22             131.82%
# 1  4,045  4,324              -6.45%
# 2    159    222             -28.38%
# 3    110     81              35.80%
# 4     65     84             -22.62%
#
#   Percentage of Total Homeless Populaiton (2013)  Rate per 10,000
# 0                                           4.0%             3.20
# 1                                           5.2%             2.06
# 2                                           5.3%             1.20
# 3                                           5.3%             1.52
# 4                                           6.9%             0.70

# %%
df.isna().sum()
# Out:
# ID                                                  0
# State                                               0
# Variable                                            0
# 2013                                                0
# 2012                                              108
# %  Change from 2012                               108
# Percentage of Total Homeless Populaiton (2013)    108
# Rate per 10,000                                   163
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['ID', 'State', 'Variable', '2013', '2012', '%  Change from 2012',
#        'Percentage of Total Homeless Populaiton (2013)', 'Rate per 10,000'],
#       dtype='str')

# %%
df.columns = df.columns.str.strip()

# %%
print(list(df.columns))
# Out:
# ['ID', 'State', 'Variable', '2013', '2012', '%  Change from 2012', 'Percentage of Total Homeless Populaiton (2013)', 'Rate per 10,000']
