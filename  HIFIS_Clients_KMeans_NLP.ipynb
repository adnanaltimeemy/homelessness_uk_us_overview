# %%
import pandas as pd
import numpy as np

from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
import seaborn as sns

import nltk
from nltk.corpus import stopwords
import string

# %%
df = pd.read_csv("HIFIS_Clients_example.csv")

df.head()
# Out:
#    ClientID  PersonID           ConsentType  FamilyID  RelationshipType  \
# 0         0         0  Declined - Anonymous       NaN               NaN
# 1         0         0  Declined - Anonymous       NaN               NaN
#
#                DOB  CurrentAge Gender AboriginalIndicator  \
# 0  1973-08-23 0:00          47   Male      Non-Indigenous
# 1  1973-08-23 0:00          47   Male      Non-Indigenous
#
#                          Citizenship  ... DietCatetory FoodType AvoidedDietYN  \
# 0  Canadian Citizen - Born in Canada  ...          NaN      NaN           NaN
# 1  Canadian Citizen - Born in Canada  ...          NaN      NaN           NaN
#
#   IntakeID  PreScreenPeriod TotalScore  ClientBarredPeriodID  Reason Modules  \
# 0      NaN              NaN        NaN                   NaN     NaN     NaN
# 1      NaN              NaN        NaN                   NaN     NaN     NaN
#
#    ServiceRestricitonOrganizationName
# 0                                 NaN
# 1                                 NaN
#
# [2 rows x 61 columns]

# %%
print(df.columns.tolist())
# Out:
# ['ClientID', 'PersonID', 'ConsentType', 'FamilyID', 'RelationshipType', 'DOB', 'CurrentAge', 'Gender', 'AboriginalIndicator', 'Citizenship', 'VeteranStatus', 'CountryOfBirth', 'ProvinceOfBirth', 'CityOfBirth', 'EyeColour', 'HairColour', 'ClientHeightCM', 'ClientWeightKG', 'InHousing', 'MovedInDate', 'ServiceID', 'ServiceType', 'DateStart', 'DateEnd', 'ReasonForService', 'OrganizationName', 'IncomeType', 'MonthlyAmount', 'ClientExpenseID', 'ExpenseType', 'ExpenseAmount', 'ExpenseFrequency', 'IsEssentialYN', 'EducationLevel', 'EducationStartDate', 'EducationEndDate', 'HealthIssueID', 'HealthIssue', 'DiagnosedYN', 'SelfReportedYN', 'SuspectedYN', 'HealthIssuesMedicationName', 'OtherMedications', 'clientContributingFactorID', 'ContributingFactor', 'ClientBehaviouralFactorID', 'BehavioralFactor', 'Severity', 'PeopleLifeEventID', 'LifeEvent', 'ClientDietID', 'DietCatetory', 'FoodType', 'AvoidedDietYN', 'IntakeID', 'PreScreenPeriod', 'TotalScore', 'ClientBarredPeriodID', 'Reason', 'Modules', 'ServiceRestricitonOrganizationName']

# %%
print(df.columns)
# Out:
# Index(['ClientID', 'PersonID', 'ConsentType', 'FamilyID', 'RelationshipType',
#        'DOB', 'CurrentAge', 'Gender', 'AboriginalIndicator', 'Citizenship',
#        'VeteranStatus', 'CountryOfBirth', 'ProvinceOfBirth', 'CityOfBirth',
#        'EyeColour', 'HairColour', 'ClientHeightCM', 'ClientWeightKG',
#        'InHousing', 'MovedInDate', 'ServiceID', 'ServiceType', 'DateStart',
#        'DateEnd', 'ReasonForService', 'OrganizationName', 'IncomeType',
#        'MonthlyAmount', 'ClientExpenseID', 'ExpenseType', 'ExpenseAmount',
#        'ExpenseFrequency', 'IsEssentialYN', 'EducationLevel',
#        'EducationStartDate', 'EducationEndDate', 'HealthIssueID',
#        'HealthIssue', 'DiagnosedYN', 'SelfReportedYN', 'SuspectedYN',
#        'HealthIssuesMedicationName', 'OtherMedications',
#        'clientContributingFactorID', 'ContributingFactor',
#        'ClientBehaviouralFactorID', 'BehavioralFactor', 'Severity',
#        'PeopleLifeEventID', 'LifeEvent', 'ClientDietID', 'DietCatetory',
#        'FoodType', 'AvoidedDietYN', 'IntakeID', 'PreScreenPeriod',
#        'TotalScore', 'ClientBarredPeriodID', 'Reason', 'Modules',
#        'ServiceRestricitonOrganizationName'],
#       dtype='str')

# %%
list(df.columns)
# Out:
# ['ClientID',
#  'PersonID',
#  'ConsentType',
#  'FamilyID',
#  'RelationshipType',
#  'DOB',
#  'CurrentAge',
#  'Gender',
#  'AboriginalIndicator',
#  'Citizenship',
#  'VeteranStatus',
#  'CountryOfBirth',
#  'ProvinceOfBirth',
#  'CityOfBirth',
#  'EyeColour',
#  'HairColour',
#  'ClientHeightCM',
#  'ClientWeightKG',
#  'InHousing',
#  'MovedInDate',
#  'ServiceID',
#  'ServiceType',
#  'DateStart',
#  'DateEnd',
#  'ReasonForService',
#  'OrganizationName',
#  'IncomeType',
#  'MonthlyAmount',
#  'ClientExpenseID',
#  'ExpenseType',
#  'ExpenseAmount',
#  'ExpenseFrequency',
#  'IsEssentialYN',
#  'EducationLevel',
#  'EducationStartDate',
#  'EducationEndDate',
#  'HealthIssueID',
#  'HealthIssue',
#  'DiagnosedYN',
#  'SelfReportedYN',
#  'SuspectedYN',
#  'HealthIssuesMedicationName',
#  'OtherMedications',
#  'clientContributingFactorID',
#  'ContributingFactor',
#  'ClientBehaviouralFactorID',
#  'BehavioralFactor',
#  'Severity',
#  'PeopleLifeEventID',
#  'LifeEvent',
#  'ClientDietID',
#  'DietCatetory',
#  'FoodType',
#  'AvoidedDietYN',
#  'IntakeID',
#  'PreScreenPeriod',
#  'TotalScore',
#  'ClientBarredPeriodID',
#  'Reason',
#  'Modules',
#  'ServiceRestricitonOrganizationName']

# %%
df.columns = df.columns.str.strip()

# %%
print(df.columns)
# Out:
# Index(['ClientID', 'PersonID', 'ConsentType', 'FamilyID', 'RelationshipType',
#        'DOB', 'CurrentAge', 'Gender', 'AboriginalIndicator', 'Citizenship',
#        'VeteranStatus', 'CountryOfBirth', 'ProvinceOfBirth', 'CityOfBirth',
#        'EyeColour', 'HairColour', 'ClientHeightCM', 'ClientWeightKG',
#        'InHousing', 'MovedInDate', 'ServiceID', 'ServiceType', 'DateStart',
#        'DateEnd', 'ReasonForService', 'OrganizationName', 'IncomeType',
#        'MonthlyAmount', 'ClientExpenseID', 'ExpenseType', 'ExpenseAmount',
#        'ExpenseFrequency', 'IsEssentialYN', 'EducationLevel',
#        'EducationStartDate', 'EducationEndDate', 'HealthIssueID',
#        'HealthIssue', 'DiagnosedYN', 'SelfReportedYN', 'SuspectedYN',
#        'HealthIssuesMedicationName', 'OtherMedications',
#        'clientContributingFactorID', 'ContributingFactor',
#        'ClientBehaviouralFactorID', 'BehavioralFactor', 'Severity',
#        'PeopleLifeEventID', 'LifeEvent', 'ClientDietID', 'DietCatetory',
#        'FoodType', 'AvoidedDietYN', 'IntakeID', 'PreScreenPeriod',
#        'TotalScore', 'ClientBarredPeriodID', 'Reason', 'Modules',
#        'ServiceRestricitonOrganizationName'],
#       dtype='str')

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [ClientID, PersonID, ConsentType, FamilyID, RelationshipType, DOB, CurrentAge, Gender, AboriginalIndicator, Citizenship, VeteranStatus, CountryOfBirth, ProvinceOfBirth, CityOfBirth, EyeColour, HairColour, ClientHeightCM, ClientWeightKG, InHousing, MovedInDate, ServiceID, ServiceType, DateStart, DateEnd, ReasonForService, OrganizationName, IncomeType, MonthlyAmount, ClientExpenseID, ExpenseType, ExpenseAmount, ExpenseFrequency, IsEssentialYN, EducationLevel, EducationStartDate, EducationEndDate, HealthIssueID, HealthIssue, DiagnosedYN, SelfReportedYN, SuspectedYN, HealthIssuesMedicationName, OtherMedications, clientContributingFactorID, ContributingFactor, ClientBehaviouralFactorID, BehavioralFactor, Severity, PeopleLifeEventID, LifeEvent, ClientDietID, DietCatetory, FoodType, AvoidedDietYN, IntakeID, PreScreenPeriod, TotalScore, ClientBarredPeriodID, Reason, Modules, ServiceRestricitonOrganizationName]
# Index: []
#
# [0 rows x 61 columns]

# %%
print(df.columns)
# Out:
# Index(['ClientID', 'PersonID', 'ConsentType', 'FamilyID', 'RelationshipType',
#        'DOB', 'CurrentAge', 'Gender', 'AboriginalIndicator', 'Citizenship',
#        'VeteranStatus', 'CountryOfBirth', 'ProvinceOfBirth', 'CityOfBirth',
#        'EyeColour', 'HairColour', 'ClientHeightCM', 'ClientWeightKG',
#        'InHousing', 'MovedInDate', 'ServiceID', 'ServiceType', 'DateStart',
#        'DateEnd', 'ReasonForService', 'OrganizationName', 'IncomeType',
#        'MonthlyAmount', 'ClientExpenseID', 'ExpenseType', 'ExpenseAmount',
#        'ExpenseFrequency', 'IsEssentialYN', 'EducationLevel',
#        'EducationStartDate', 'EducationEndDate', 'HealthIssueID',
#        'HealthIssue', 'DiagnosedYN', 'SelfReportedYN', 'SuspectedYN',
#        'HealthIssuesMedicationName', 'OtherMedications',
#        'clientContributingFactorID', 'ContributingFactor',
#        'ClientBehaviouralFactorID', 'BehavioralFactor', 'Severity',
#        'PeopleLifeEventID', 'LifeEvent', 'ClientDietID', 'DietCatetory',
#        'FoodType', 'AvoidedDietYN', 'IntakeID', 'PreScreenPeriod',
#        'TotalScore', 'ClientBarredPeriodID', 'Reason', 'Modules',
#        'ServiceRestricitonOrganizationName'],
#       dtype='str')

# %%
print(df.columns)
# Out:
# Index(['ClientID', 'PersonID', 'ConsentType', 'FamilyID', 'RelationshipType',
#        'DOB', 'CurrentAge', 'Gender', 'AboriginalIndicator', 'Citizenship',
#        'VeteranStatus', 'CountryOfBirth', 'ProvinceOfBirth', 'CityOfBirth',
#        'EyeColour', 'HairColour', 'ClientHeightCM', 'ClientWeightKG',
#        'InHousing', 'MovedInDate', 'ServiceID', 'ServiceType', 'DateStart',
#        'DateEnd', 'ReasonForService', 'OrganizationName', 'IncomeType',
#        'MonthlyAmount', 'ClientExpenseID', 'ExpenseType', 'ExpenseAmount',
#        'ExpenseFrequency', 'IsEssentialYN', 'EducationLevel',
#        'EducationStartDate', 'EducationEndDate', 'HealthIssueID',
#        'HealthIssue', 'DiagnosedYN', 'SelfReportedYN', 'SuspectedYN',
#        'HealthIssuesMedicationName', 'OtherMedications',
#        'clientContributingFactorID', 'ContributingFactor',
#        'ClientBehaviouralFactorID', 'BehavioralFactor', 'Severity',
#        'PeopleLifeEventID', 'LifeEvent', 'ClientDietID', 'DietCatetory',
#        'FoodType', 'AvoidedDietYN', 'IntakeID', 'PreScreenPeriod',
#        'TotalScore', 'ClientBarredPeriodID', 'Reason', 'Modules',
#        'ServiceRestricitonOrganizationName'],
#       dtype='str')

# %%
print(df.columns)
plt.show()
# Out:
# Index(['ClientID', 'PersonID', 'ConsentType', 'FamilyID', 'RelationshipType',
#        'DOB', 'CurrentAge', 'Gender', 'AboriginalIndicator', 'Citizenship',
#        'VeteranStatus', 'CountryOfBirth', 'ProvinceOfBirth', 'CityOfBirth',
#        'EyeColour', 'HairColour', 'ClientHeightCM', 'ClientWeightKG',
#        'InHousing', 'MovedInDate', 'ServiceID', 'ServiceType', 'DateStart',
#        'DateEnd', 'ReasonForService', 'OrganizationName', 'IncomeType',
#        'MonthlyAmount', 'ClientExpenseID', 'ExpenseType', 'ExpenseAmount',
#        'ExpenseFrequency', 'IsEssentialYN', 'EducationLevel',
#        'EducationStartDate', 'EducationEndDate', 'HealthIssueID',
#        'HealthIssue', 'DiagnosedYN', 'SelfReportedYN', 'SuspectedYN',
#        'HealthIssuesMedicationName', 'OtherMedications',
#        'clientContributingFactorID', 'ContributingFactor',
#        'ClientBehaviouralFactorID', 'BehavioralFactor', 'Severity',
#        'PeopleLifeEventID', 'LifeEvent', 'ClientDietID', 'DietCatetory',
#        'FoodType', 'AvoidedDietYN', 'IntakeID', 'PreScreenPeriod',
#        'TotalScore', 'ClientBarredPeriodID', 'Reason', 'Modules',
#        'ServiceRestricitonOrganizationName'],
#       dtype='str')

# %%
df.columns = df.columns.str.strip()

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [ClientID, PersonID, ConsentType, FamilyID, RelationshipType, DOB, CurrentAge, Gender, AboriginalIndicator, Citizenship, VeteranStatus, CountryOfBirth, ProvinceOfBirth, CityOfBirth, EyeColour, HairColour, ClientHeightCM, ClientWeightKG, InHousing, MovedInDate, ServiceID, ServiceType, DateStart, DateEnd, ReasonForService, OrganizationName, IncomeType, MonthlyAmount, ClientExpenseID, ExpenseType, ExpenseAmount, ExpenseFrequency, IsEssentialYN, EducationLevel, EducationStartDate, EducationEndDate, HealthIssueID, HealthIssue, DiagnosedYN, SelfReportedYN, SuspectedYN, HealthIssuesMedicationName, OtherMedications, clientContributingFactorID, ContributingFactor, ClientBehaviouralFactorID, BehavioralFactor, Severity, PeopleLifeEventID, LifeEvent, ClientDietID, DietCatetory, FoodType, AvoidedDietYN, IntakeID, PreScreenPeriod, TotalScore, ClientBarredPeriodID, Reason, Modules, ServiceRestricitonOrganizationName]
# Index: []
#
# [0 rows x 61 columns]

# %%
df.columns
# Out:
# Index(['ClientID', 'PersonID', 'ConsentType', 'FamilyID', 'RelationshipType',
#        'DOB', 'CurrentAge', 'Gender', 'AboriginalIndicator', 'Citizenship',
#        'VeteranStatus', 'CountryOfBirth', 'ProvinceOfBirth', 'CityOfBirth',
#        'EyeColour', 'HairColour', 'ClientHeightCM', 'ClientWeightKG',
#        'InHousing', 'MovedInDate', 'ServiceID', 'ServiceType', 'DateStart',
#        'DateEnd', 'ReasonForService', 'OrganizationName', 'IncomeType',
#        'MonthlyAmount', 'ClientExpenseID', 'ExpenseType', 'ExpenseAmount',
#        'ExpenseFrequency', 'IsEssentialYN', 'EducationLevel',
#        'EducationStartDate', 'EducationEndDate', 'HealthIssueID',
#        'HealthIssue', 'DiagnosedYN', 'SelfReportedYN', 'SuspectedYN',
#        'HealthIssuesMedicationName', 'OtherMedications',
#        'clientContributingFactorID', 'ContributingFactor',
#        'ClientBehaviouralFactorID', 'BehavioralFactor', 'Severity',
#        'PeopleLifeEventID', 'LifeEvent', 'ClientDietID', 'DietCatetory',
#        'FoodType', 'AvoidedDietYN', 'IntakeID', 'PreScreenPeriod',
#        'TotalScore', 'ClientBarredPeriodID', 'Reason', 'Modules',
#        'ServiceRestricitonOrganizationName'],
#       dtype='str')
